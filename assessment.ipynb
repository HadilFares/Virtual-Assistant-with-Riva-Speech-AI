# %% [markdown]
# <a href="https://www.nvidia.com/dli"> <img src="images/DLI_Header.png" alt="Header" style="width: 400px;"/> </a>

# %% [markdown]
# # Assessment: Virtual Assistant with Riva Speech AI and Question Answering
#
# Question answering (QA) tasks consists of generating an answer, given a natural language query and a context (knowledge content).
#
# - **Extractive QA**: Predict the span within the context with a start and end position which indicates the answer to the question.
# - **Generative QA**: Generate a natural answer for the query with no constraint that the answer should be a span within the context.  This could be built using an LLM endpoint.
#
# Riva supports out-of-the-box extractive QA with a BERT model, and that is what you'll use for this assessment.
#
# <img src="images/assess/bert_QA.png" width=500>
#
# ### Table of Contents
# [The Problem](#The-Problem)<br>
# [Scoring](#Scoring)<br>
# [Step 1: Launch Riva Server](#Step-1:-Launch-Riva-Server)<br>
# [Step 2: ASR Query](#Step-2:-ASR-Query)<br>
# [Step 3: ASR Customization](#Step-3:-ASR-Customization)<br>
# [Step 4: Question Answering](#Step-4:-Question-Answering)<br>
# [Step 5: TTS Query](#Step-5:-TTS-Query)<br>
# [Step 6: Simple Virtual Assistant](#Step-6:-Simple-Virtual-Assistant)<br>
# [Step 7: Submit Your Assessment](#Step-7:-Submit-Your-Assessment)<br>

# %% [markdown]
# ### Notebook Dependencies
# To successfully run this notebook, be sure you have:
#
# 1. **NGC Credentials**<br>Be sure you have added your NGC credential as described in the [NGC Setup notebook](003_Intro_NGC_Setup.ipynb).  If you have restarted the course instance, you will need to repeat this step.
#
# 2. **Killed all Docker containers**<br>Run the following cell to make sure all containers are shut down.

# %%
# Start fresh...
# Clear Docker containers
# !docker kill $(docker ps -q)
# Check for clean environment - this should be empty
# !docker ps
# Out:
# "docker kill" requires at least 1 argument.
# See 'docker kill --help'.
#
# Usage:  docker kill [OPTIONS] CONTAINER [CONTAINER...]
#
# Kill one or more running containers
# CONTAINER ID   IMAGE     COMMAND   CREATED   STATUS    PORTS     NAMES

# %% [markdown]
# 3. **Cleared GPU Memory**<br>
# Make sure you have shut down all other notebooks to fully clear GPU memory.  Verify this is the case by running the following cell and observing the Memory Usage information.

# %%
# !nvidia-smi
# Out:
# Sat Nov  8 19:57:14 2025
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 510.47.03    Driver Version: 510.47.03    CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A10G         Off  | 00000000:00:1E.0 Off |                    0 |
# |  0%   24C    P8     9W / 300W |      0MiB / 23028MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ---
# # The Problem
# In this assessment, you'll build a virtual assistant application that integrates ASR, TTS, and NLP services to answer questions about EMEA (Europe, Middle East, and Africa).  Your virtual assistant should be able to answer an audio question about EMEA and respond in speech with the answer to the question!
#
# <img src="images/assess/IVA_QA.png">
#
# You'll need to add some customizations along the way to make this work properly for EMEA. In summary, you'll:
# - Launch Riva ASR, TTS, and NLP (includes QA) services
# - Customize the virtual assistant transcriber to recognize "EMEA"
# - Build a simple dialog manager (DM) with extractive QA from external documents about EMEA
# - Customize the virtual assistant pronunciation of "EMEA"
# - Run the virtual assistant end-to-end for a complete conversational AI dialog

# %% [markdown]
# ---
# # Scoring
# You will be assessed on your ability to effectively and efficiently build and deploy the application.  This coding assessment is worth 70 points, divided as follows:
#
#
# | Step                         | Graded                                                    | FIXMEs?  | Points |
# |------------------------------|-----------------------------------------------------------|----------|--------|
# | 1. Launch Riva               | Riva Server (correct config; models run)                  |    4     |   12   |
# | 2. ASR Query            | Request for transcription (check ASR config )                  |    3     |    9   |
# | 3. ASR Customization    | Improve transcription with ASR customization (evaluate error)  |    3     |   15   |
# | 4. Question Answering   | Request Q&A on new context (check returned answer)             |    2     |   10   |
# | 5. TTS Query            | Request for TTS (check TTS config )                            |    3     |    9   |
# | 6. Simple Virtual Assistant  | Put all together (check answer)                           |    3     |   15   |
#
#
# Although you are very capable at this point of building the project without any help at all, some scaffolding is provided, including specific names for variables and files.  This is for the benefit of the autograder, so please use these constructs for your assessment.  In addition, output for your executed cells is periodically saved in the `my_assessment` directory for grading.  Along the way, there are a few opportunities to check your work to see if you are on the right track.
#
# Once you are confident that you've built a reliable virtual assistant, follow the instructions for submission at the end of the notebook.
#
# ### Resources and Hints
#
# * **[Riva Speech Skills User's Guide](https://docs.nvidia.com/deeplearning/riva/user-guide/docs/index.html)**<br>
# * **Riva Deployment Examples**<br>
# Review what you've learned in the [ASR Deployment](005_ASR_Deployment.ipynb) and [TTS Deployment](007_TTS_Deployment.ipynb) notebooks about how to deploy and query Riva ASR/TTS services.
# * **Riva Customization Examples**<br>
# Review what you've learned in the [Full Pipeline](008_Full_Pipeline.ipynb) notebook about building a simple dialog manager and customizing Riva ASR/TTS services.

# %% [markdown]
# ---
# # Step 1: Launch Riva Server
# ### Set Up Project Paths, Libraries, and Models (not graded)
# For the full pipeline, we'll need to deploy default models for ASR, TTS, and NLP services. The `riva_init.sh` command loads and builds models specific to the GPU you are using, but to save time for this course, these have been preloaded.
#
# The next few cells create some useful path names and copy all of the optimized models into `/dli_workspace/riva-assessment-model-repo` for convenience.  This is the repo you must use for the assessment.

# %%
# Set the Riva Quick Start directory and model repo
WORKSPACE='/dli_workspace'
RIVA_QS = WORKSPACE + "/riva_quickstart"
RIVA_MODEL_REPO = WORKSPACE + "/riva-assessment-model-repo"
# !mkdir -p $RIVA_MODEL_REPO

# load required libraries
import riva.client
import numpy as np
import IPython.display as ipd
import io
import time
import librosa

# %%
# Models have been preloaded, so TensorRT builds ("deployment") will be skipped
# Run this check to make sure required models and docker images are loaded
# Expect loading to take over 10 minutes from inital launch of course instance

import os
import time

# Check for download complete every 30 seconds
while not os.path.isfile("/dli/task/dli_workspace/riva-asr-model-repo/asr_download_complete") \
    or not os.path.isfile("/dli/task/dli_workspace/riva-tts-model-repo/tts_download_complete") \
    or not os.path.isfile("/dli/task/dli_workspace/riva-full-model-repo/nlp_download_complete") \
    or not os.path.isfile("/dli/task/dli_workspace/docker_images_loaded"):
    print("Download still in progress. Checking again in 30 seconds...")
    time.sleep(30)
print("Download is complete.")
# Out:
# Download is complete.

# %%
# %%bash
# # Copy all the ASR, TTS, and NLP models for convenience (faster deployment)
# # Time is about 1-2 minutes for the copy
# cp -rn  /dli_workspace/riva-asr-model-repo/* \
#     /dli_workspace/riva-assessment-model-repo/
#
# cp -rn  /dli_workspace/riva-tts-model-repo/* \
#     /dli_workspace/riva-assessment-model-repo/
#
# cp -rn  /dli_workspace/riva-full-model-repo/* \
#     /dli_workspace/riva-assessment-model-repo/

# %%
# check to see what models are there now
# !ls $RIVA_MODEL_REPO/models
# Out:
# conformer-en-US-asr-offline
# conformer-en-US-asr-offline-ctc-decoder-cpu-streaming-offline
# conformer-en-US-asr-offline-endpointing-streaming-offline
# conformer-en-US-asr-offline-feature-extractor-streaming-offline
# conformer-en-US-asr-streaming
# conformer-en-US-asr-streaming-ctc-decoder-cpu-streaming
# conformer-en-US-asr-streaming-endpointing-streaming
# conformer-en-US-asr-streaming-feature-extractor-streaming
# conformer-es-US-asr-offline
# conformer-es-US-asr-offline-ctc-decoder-cpu-streaming-offline
# conformer-es-US-asr-offline-endpointing-streaming-offline
# conformer-es-US-asr-offline-feature-extractor-streaming-offline
# conformer-es-US-asr-streaming
# conformer-es-US-asr-streaming-ctc-decoder-cpu-streaming
# conformer-es-US-asr-streaming-endpointing-streaming
# conformer-es-US-asr-streaming-feature-extractor-streaming
# fastpitch_hifigan_ensemble-English-US
# intent_slot_detokenizer
# intent_slot_label_tokens_weather
# intent_slot_tokenizer-en-US-weather
# qa_qa_postprocessor
# qa_tokenizer-en-US
# riva-onnx-fastpitch_encoder-English-US
# riva-punctuation-en-US
# riva-punctuation-es-US
# riva-trt-conformer-en-US-asr-offline-am-streaming-offline
# riva-trt-conformer-en-US-asr-streaming-am-streaming
# riva-trt-conformer-es-US-asr-offline-am-streaming-offline
# riva-trt-conformer-es-US-asr-streaming-am-streaming
# riva-trt-hifigan-English-US
# riva-trt-riva-punctuation-en-US-nn-bert-base-uncased
# riva-trt-riva-punctuation-es-US-nn-bert-base-multilingual-uncased
# riva-trt-riva_intent_weather-nn-bert-base-uncased
# riva-trt-riva_ner-nn-bert-base-uncased
# riva-trt-riva_qa-nn-bert-base-uncased
# riva-trt-riva_text_classification_domain-nn-bert-base-uncased
# riva_intent_weather
# riva_ner
# riva_qa
# riva_text_classification_domain
# spectrogram_chunker-English-US
# text_classification_tokenizer-en-US-domain
# token_classification_detokenizer
# token_classification_label_tokens
# token_classification_tokenizer-en-US
# tts_postprocessor-English-US
# tts_preprocessor-English-US

# %% [markdown]
# ### Configure Riva (graded)
#
# Open [config.sh](dli_workspace/riva_quickstart/config.sh) and modify it to deploy all three services (ASR, NLP, TTS) with the out-of-the-box default models, specifying the newly created model repository created above for this assessment. Save your work.
# ```
#  service_enabled_asr=FIXME
#  service_enabled_nlp=FIXME
#  service_enabled_tts=FIXME
#  riva_model_loc=FIXME
# ```

# %%
# Check your work - are all three services enabled? Is the model location repo correct? 
! cat dli_workspace/riva_quickstart/config.sh \
   2>&1|tee my_assessment/step1.txt # DO NOT REMOVE THIS LINE
# Out:
# tee: my_assessment/step1.txt: No such file or directory
# cat: dli_workspace/riva_quickstart/config.sh: No such file or directory

# %% [markdown]
# ### Launch Riva Server (not graded)

# %%
# Start the Riva server (about 1 minute)
# !cd $RIVA_QS && bash riva_start.sh config.sh
# Out:
# Starting Riva Speech Services. This may take several minutes depending on the number of models deployed.
# a6815b854df56909ddfce57941700e71a1d37b83dcd0b123c3fe5719d6d93c2e
# Waiting for Riva server to load all models...retrying in 10 seconds
# Waiting for Riva server to load all models...retrying in 10 seconds
# Waiting for Riva server to load all models...retrying in 10 seconds
# Waiting for Riva server to load all models...retrying in 10 seconds
# Waiting for Riva server to load all models...retrying in 10 seconds
# Waiting for Riva server to load all models...retrying in 10 seconds
# Waiting for Riva server to load all models...retrying in 10 seconds
# Waiting for Riva server to load all models...retrying in 10 seconds
# Waiting for Riva server to load all models...retrying in 10 seconds
# Waiting for Riva server to load all models...retrying in 10 seconds
# Waiting for Riva server to load all models...retrying in 10 seconds
# Waiting for Riva server to load all models...retrying in 10 seconds
# Waiting for Riva server to load all models...retrying in 10 seconds
# Waiting for Riva server to load all models...retrying in 10 seconds
# Waiting for Riva server to load all models...retrying in 10 seconds
# Waiting for Riva server to load all models...retrying in 10 seconds
# Waiting for Riva server to load all models...retrying in 10 seconds
# Waiting for Riva server to load all models...retrying in 10 seconds
# Waiting for Riva server to load all models...retrying in 10 seconds
# Waiting for Riva server to load all models...retrying in 10 seconds
# Waiting for Riva server to load all models...retrying in 10 seconds
# Waiting for Riva server to load all models...retrying in 10 seconds
# Waiting for Riva server to load all models...retrying in 10 seconds
# Waiting for Riva server to load all models...retrying in 10 seconds
# Waiting for Riva server to load all models...retrying in 10 seconds
# Waiting for Riva server to load all models...retrying in 10 seconds
# Waiting for Riva server to load all models...retrying in 10 seconds
# Waiting for Riva server to load all models...retrying in 10 seconds
# Waiting for Riva server to load all models...retrying in 10 seconds
# Waiting for Riva server to load all models...retrying in 10 seconds
# Health ready check failed.
# Check Riva logs with: docker logs riva-speech

# %%
! docker logs riva-speech
# Out:
# ==========================
# === Riva Speech Skills ===
# ==========================
#
# NVIDIA Release  (build 49655088)
#
# Copyright (c) 2018-2022, NVIDIA CORPORATION & AFFILIATES. All rights reserved.
#
# Various files include modifications (c) NVIDIA CORPORATION & AFFILIATES.  All rights reserved.
#
# This container image and its contents are governed by the NVIDIA Deep Learning Container License.
# By pulling and using the container, you accept the terms and conditions of this license:
# https://developer.nvidia.com/ngc/nvidia-deep-learning-container-license
#
# NOTE: CUDA Forward Compatibility mode ENABLED.
#   Using CUDA 11.8 driver version 520.61.05 with kernel driver version 510.47.03.
#   See https://docs.nvidia.com/deploy/cuda-compatibility/ for details.
#
#   > Riva waiting for Triton server to load all models...retrying in 1 second
# Warning: '--strict-model-config' has been deprecated! Please use '--disable-auto-complete-config' instead.
# I1108 23:44:41.977900 105 pinned_memory_manager.cc:240] Pinned memory pool is created at '0x7fdf48000000' with size 268435456
# I1108 23:44:41.978266 105 cuda_memory_manager.cc:105] CUDA memory pool is created on device 0 with size 1000000000
# I1108 23:44:42.011639 105 model_lifecycle.cc:459] loading: conformer-en-US-asr-offline-ctc-decoder-cpu-streaming-offline:1
# I1108 23:44:42.011723 105 model_lifecycle.cc:459] loading: conformer-en-US-asr-offline-endpointing-streaming-offline:1
# I1108 23:44:42.011846 105 model_lifecycle.cc:459] loading: conformer-en-US-asr-offline-feature-extractor-streaming-offline:1
# I1108 23:44:42.011970 105 model_lifecycle.cc:459] loading: conformer-en-US-asr-streaming-ctc-decoder-cpu-streaming:1
# I1108 23:44:42.012046 105 model_lifecycle.cc:459] loading: conformer-en-US-asr-streaming-endpointing-streaming:1
# I1108 23:44:42.012172 105 model_lifecycle.cc:459] loading: conformer-en-US-asr-streaming-feature-extractor-streaming:1
# I1108 23:44:42.012296 105 model_lifecycle.cc:459] loading: conformer-es-US-asr-offline-ctc-decoder-cpu-streaming-offline:1
# I1108 23:44:42.012359 105 model_lifecycle.cc:459] loading: conformer-es-US-asr-offline-endpointing-streaming-offline:1
# I1108 23:44:42.012399 105 model_lifecycle.cc:459] loading: conformer-es-US-asr-offline-feature-extractor-streaming-offline:1
# I1108 23:44:42.012440 105 model_lifecycle.cc:459] loading: conformer-es-US-asr-streaming-ctc-decoder-cpu-streaming:1
# I1108 23:44:42.012478 105 model_lifecycle.cc:459] loading: conformer-es-US-asr-streaming-endpointing-streaming:1
# I1108 23:44:42.012512 105 model_lifecycle.cc:459] loading: conformer-es-US-asr-streaming-feature-extractor-streaming:1
# I1108 23:44:42.012537 105 model_lifecycle.cc:459] loading: intent_slot_detokenizer:1
# I1108 23:44:42.012566 105 model_lifecycle.cc:459] loading: intent_slot_label_tokens_weather:1
# I1108 23:44:42.012589 105 model_lifecycle.cc:459] loading: intent_slot_tokenizer-en-US-weather:1
# I1108 23:44:42.012613 105 model_lifecycle.cc:459] loading: qa_qa_postprocessor:1
# I1108 23:44:42.012639 105 model_lifecycle.cc:459] loading: qa_tokenizer-en-US:1
# I1108 23:44:42.012669 105 model_lifecycle.cc:459] loading: riva-onnx-fastpitch_encoder-English-US:1
# I1108 23:44:42.012720 105 model_lifecycle.cc:459] loading: riva-punctuation-en-US:1
# I1108 23:44:42.012771 105 model_lifecycle.cc:459] loading: riva-punctuation-es-US:1
# I1108 23:44:42.012801 105 model_lifecycle.cc:459] loading: riva-trt-conformer-en-US-asr-offline-am-streaming-offline:1
# I1108 23:44:42.012826 105 model_lifecycle.cc:459] loading: riva-trt-conformer-en-US-asr-streaming-am-streaming:1
# I1108 23:44:42.012864 105 model_lifecycle.cc:459] loading: riva-trt-conformer-es-US-asr-offline-am-streaming-offline:1
# I1108 23:44:42.012901 105 model_lifecycle.cc:459] loading: riva-trt-conformer-es-US-asr-streaming-am-streaming:1
# I1108 23:44:42.012927 105 model_lifecycle.cc:459] loading: riva-trt-hifigan-English-US:1
# I1108 23:44:42.012979 105 model_lifecycle.cc:459] loading: riva-trt-riva-punctuation-en-US-nn-bert-base-uncased:1
# I1108 23:44:42.013006 105 model_lifecycle.cc:459] loading: riva-trt-riva-punctuation-es-US-nn-bert-base-multilingual-uncased:1
# I1108 23:44:42.013033 105 model_lifecycle.cc:459] loading: riva-trt-riva_intent_weather-nn-bert-base-uncased:1
# I1108 23:44:42.013084 105 model_lifecycle.cc:459] loading: riva-trt-riva_ner-nn-bert-base-uncased:1
# I1108 23:44:42.013114 105 model_lifecycle.cc:459] loading: riva-trt-riva_qa-nn-bert-base-uncased:1
# I1108 23:44:42.013139 105 model_lifecycle.cc:459] loading: riva-trt-riva_text_classification_domain-nn-bert-base-uncased:1
# I1108 23:44:42.013166 105 model_lifecycle.cc:459] loading: spectrogram_chunker-English-US:1
# I1108 23:44:42.013193 105 model_lifecycle.cc:459] loading: text_classification_tokenizer-en-US-domain:1
# I1108 23:44:42.013220 105 model_lifecycle.cc:459] loading: token_classification_detokenizer:1
# I1108 23:44:42.013287 105 model_lifecycle.cc:459] loading: token_classification_label_tokens:1
# I1108 23:44:42.013336 105 model_lifecycle.cc:459] loading: token_classification_tokenizer-en-US:1
# I1108 23:44:42.013386 105 model_lifecycle.cc:459] loading: tts_postprocessor-English-US:1
# I1108 23:44:42.013437 105 model_lifecycle.cc:459] loading: tts_preprocessor-English-US:1
# I1108 23:44:42.059708 105 endpointing_library.cc:18] TRITONBACKEND_ModelInitialize: conformer-en-US-asr-offline-endpointing-streaming-offline (version 1)
# WARNING: Logging before InitGoogleLogging() is written to STDERR
# W1108 23:44:42.060458   112 parameter_parser.cc:144] Parameter 'chunk_size' set but unused.
# W1108 23:44:42.060479   112 parameter_parser.cc:144] Parameter 'ms_per_timestep' set but unused.
# W1108 23:44:42.060482   112 parameter_parser.cc:144] Parameter 'residue_blanks_at_end' set but unused.
# W1108 23:44:42.060483   112 parameter_parser.cc:144] Parameter 'residue_blanks_at_start' set but unused.
# W1108 23:44:42.060484   112 parameter_parser.cc:144] Parameter 'start_history' set but unused.
# W1108 23:44:42.060487   112 parameter_parser.cc:144] Parameter 'start_th' set but unused.
# W1108 23:44:42.060488   112 parameter_parser.cc:144] Parameter 'stop_history' set but unused.
# W1108 23:44:42.060489   112 parameter_parser.cc:144] Parameter 'stop_th' set but unused.
# W1108 23:44:42.060492   112 parameter_parser.cc:144] Parameter 'streaming' set but unused.
# W1108 23:44:42.060493   112 parameter_parser.cc:144] Parameter 'use_subword' set but unused.
# W1108 23:44:42.060494   112 parameter_parser.cc:144] Parameter 'vocab_file' set but unused.
# I1108 23:44:42.061176 105 backend_model.cc:303] model configuration:
# {
#     "name": "conformer-en-US-asr-offline-endpointing-streaming-offline",
#     "platform": "",
#     "backend": "riva_asr_endpointing",
#     "version_policy": {
#         "latest": {
#             "num_versions": 1
#         }
#     },
#     "max_batch_size": 2048,
#     "input": [
#         {
#             "name": "CLASS_LOGITS",
#             "data_type": "TYPE_FP32",
#             "format": "FORMAT_NONE",
#             "dims": [
#                 -1,
#                 257
#             ],
#             "is_shape_tensor": false,
#             "allow_ragged_batch": false,
#             "optional": false
#         }
#     ],
#     "output": [
#         {
#             "name": "SEGMENTS_START_END",
#             "data_type": "TYPE_FP32",
#             "dims": [
#                 -1,
#                 2
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         }
#     ],
#     "batch_input": [],
#     "batch_output": [],
#     "optimization": {
#         "graph": {
#             "level": 0
#         },
#         "priority": "PRIORITY_DEFAULT",
#         "cuda": {
#             "graphs": false,
#             "busy_wait_events": false,
#             "graph_spec": [],
#             "output_copy_stream": true
#         },
#         "input_pinned_memory": {
#             "enable": true
#         },
#         "output_pinned_memory": {
#             "enable": true
#         },
#         "gather_kernel_buffer_threshold": 0,
#         "eager_batching": false
#     },
#     "sequence_batching": {
#         "max_sequence_idle_microseconds": 60000000,
#         "control_input": [
#             {
#                 "name": "START",
#                 "control": [
#                     {
#                         "kind": "CONTROL_SEQUENCE_START",
#                         "int32_false_true": [
#                             0,
#                             1
#                         ],
#                         "fp32_false_true": [],
#                         "bool_false_true": [],
#                         "data_type": "TYPE_INVALID"
#                     }
#                 ]
#             },
#             {
#                 "name": "READY",
#                 "control": [
#                     {
#                         "kind": "CONTROL_SEQUENCE_READY",
#                         "int32_false_true": [
#                             0,
#                             1
#                         ],
#                         "fp32_false_true": [],
#                         "bool_false_true": [],
#                         "data_type": "TYPE_INVALID"
#                     }
#                 ]
#             }
#         ],
#         "state": []
#     },
#     "instance_group": [
#         {
#             "name": "conformer-en-US-asr-offline-endpointing-streaming-offline_0",
#             "kind": "KIND_CPU",
#             "count": 1,
#             "gpus": [],
#             "secondary_devices": [],
#             "profile": [],
#             "passive": false,
#             "host_policy": ""
#         }
#     ],
#     "default_model_filename": "",
#     "cc_model_filenames": {},
#     "metric_tags": {},
#     "parameters": {
#         "vocab_file": {
#             "string_value": "/data/models/conformer-en-US-asr-offline-endpointing-streaming-offline/1/riva_decoder_vocabulary.txt"
#         },
#         "start_history": {
#             "string_value": "200"
#         },
#         "chunk_size": {
#             "string_value": "4.8"
#         },
#         "start_th": {
#             "string_value": "0.2"
#         },
#         "use_subword": {
#             "string_value": "True"
#         },
#         "endpointing_type": {
#             "string_value": "greedy_ctc"
#         },
#         "stop_history": {
#             "string_value": "800"
#         },
#         "ms_per_timestep": {
#             "string_value": "40"
#         },
#         "streaming": {
#             "string_value": "True"
#         },
#         "residue_blanks_at_start": {
#             "string_value": "-2"
#         },
#         "residue_blanks_at_end": {
#             "string_value": "0"
#         },
#         "stop_th": {
#             "string_value": "0.98"
#         }
#     },
#     "model_warmup": [],
#     "model_transaction_policy": {
#         "decoupled": false
#     }
# }
# I1108 23:44:42.070566 105 feature-extractor.cc:400] TRITONBACKEND_ModelInitialize: conformer-en-US-asr-offline-feature-extractor-streaming-offline (version 1)
# I1108 23:44:42.088473 105 backend_model.cc:303] model configuration:
# {
#     "name": "conformer-en-US-asr-offline-feature-extractor-streaming-offline",
#     "platform": "",
#     "backend": "riva_asr_features",
#     "version_policy": {
#         "latest": {
#             "num_versions": 1
#         }
#     },
#     "max_batch_size": 512,
#     "input": [
#         {
#             "name": "AUDIO_SIGNAL",
#             "data_type": "TYPE_FP32",
#             "format": "FORMAT_NONE",
#             "dims": [
#                 -1
#             ],
#             "is_shape_tensor": false,
#             "allow_ragged_batch": false,
#             "optional": false
#         },
#         {
#             "name": "SAMPLE_RATE",
#             "data_type": "TYPE_UINT32",
#             "format": "FORMAT_NONE",
#             "dims": [
#                 1
#             ],
#             "is_shape_tensor": false,
#             "allow_ragged_batch": false,
#             "optional": false
#         }
#     ],
#     "output": [
#         {
#             "name": "AUDIO_FEATURES",
#             "data_type": "TYPE_FP32",
#             "dims": [
#                 80,
#                 -1
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         },
#         {
#             "name": "AUDIO_PROCESSED",
#             "data_type": "TYPE_FP32",
#             "dims": [
#                 1
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         },
#         {
#             "name": "AUDIO_FEATURES_LENGTH",
#             "data_type": "TYPE_INT32",
#             "dims": [
#                 1
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         }
#     ],
#     "batch_input": [],
#     "batch_output": [],
#     "optimization": {
#         "graph": {
#             "level": 0
#         },
#         "priority": "PRIORITY_DEFAULT",
#         "cuda": {
#             "graphs": false,
#             "busy_wait_events": false,
#             "graph_spec": [],
#             "output_copy_stream": true
#         },
#         "input_pinned_memory": {
#             "enable": true
#         },
#         "output_pinned_memory": {
#             "enable": true
#         },
#         "gather_kernel_buffer_threshold": 0,
#         "eager_batching": false
#     },
#     "sequence_batching": {
#         "oldest": {
#             "max_candidate_sequences": 512,
#             "preferred_batch_size": [
#                 256,
#                 512
#             ],
#             "max_queue_delay_microseconds": 1000
#         },
#         "max_sequence_idle_microseconds": 60000000,
#         "control_input": [
#             {
#                 "name": "START",
#                 "control": [
#                     {
#                         "kind": "CONTROL_SEQUENCE_START",
#                         "int32_false_true": [
#                             0,
#                             1
#                         ],
#                         "fp32_false_true": [],
#                         "bool_false_true": [],
#                         "data_type": "TYPE_INVALID"
#                     }
#                 ]
#             },
#             {
#                 "name": "READY",
#                 "control": [
#                     {
#                         "kind": "CONTROL_SEQUENCE_READY",
#                         "int32_false_true": [
#                             0,
#                             1
#                         ],
#                         "fp32_false_true": [],
#                         "bool_false_true": [],
#                         "data_type": "TYPE_INVALID"
#                     }
#                 ]
#             },
#             {
#                 "name": "END",
#                 "control": [
#                     {
#                         "kind": "CONTROL_SEQUENCE_END",
#                         "int32_false_true": [
#                             0,
#                             1
#                         ],
#                         "fp32_false_true": [],
#                         "bool_false_true": [],
#                         "data_type": "TYPE_INVALID"
#                     }
#                 ]
#             },
#             {
#                 "name": "CORRID",
#                 "control": [
#                     {
#                         "kind": "CONTROL_SEQUENCE_CORRID",
#                         "int32_false_true": [],
#                         "fp32_false_true": [],
#                         "bool_false_true": [],
#                         "data_type": "TYPE_UINT64"
#                     }
#                 ]
#             }
#         ],
#         "state": []
#     },
#     "instance_group": [
#         {
#             "name": "conformer-en-US-asr-offline-feature-extractor-streaming-offline_0",
#             "kind": "KIND_GPU",
#             "count": 1,
#             "gpus": [
#                 0
#             ],
#             "secondary_devices": [],
#             "profile": [],
#             "passive": false,
#             "host_policy": ""
#         }
#     ],
#     "default_model_filename": "",
#     "cc_model_filenames": {},
#     "metric_tags": {},
#     "parameters": {
#         "streaming": {
#             "string_value": "True"
#         },
#         "max_execution_batch_size": {
#             "string_value": "512"
#         },
#         "transpose": {
#             "string_value": "False"
#         },
#         "right_padding_size": {
#             "string_value": "1.6"
#         },
#         "precalc_norm_time_steps": {
#             "string_value": "0"
#         },
#         "stddev": {
#             "string_value": "2.2668, 3.1642, 3.7079, 3.7642, 3.5349, 3.5901, 3.7640, 3.8424, 4.0145, 4.1475, 4.0457, 3.9048, 3.7709, 3.6117, 3.3188, 3.1489, 3.0615, 3.0362, 2.9929, 3.0500, 3.0341, 3.0484, 3.0103, 2.9474, 2.9128, 2.8669, 2.8332, 2.9411, 3.0378, 3.0712, 3.0190, 2.9992, 3.0124, 3.0024, 3.0275, 3.0870, 3.0656, 3.0142, 3.0493, 3.1373, 3.1135, 3.0675, 2.8828, 2.7018, 2.6296, 2.8826, 2.9325, 2.9288, 2.9271, 2.9890, 3.0137, 2.9855, 3.0839, 2.9319, 2.3512, 2.3795, 2.6191, 2.7555, 2.9326, 2.9931, 3.1543, 3.0855, 2.6820, 3.0566, 3.1272, 3.1663, 3.1836, 3.0018, 2.9089, 3.1727, 3.1626, 3.1086, 2.9804, 3.1107, 3.2998, 3.3697, 3.3716, 3.2487, 3.1597, 3.1181"
#         },
#         "window_size": {
#             "string_value": "0.025"
#         },
#         "gain": {
#             "string_value": "1.0"
#         },
#         "mean": {
#             "string_value": "-11.4412,  -9.9334,  -9.1292,  -9.0365,  -9.2804,  -9.5643,  -9.7342, -9.6925,  -9.6333,  -9.2808,  -9.1887,  -9.1422,  -9.1397,  -9.2028, -9.2749,  -9.4776,  -9.9185, -10.1557, -10.3800, -10.5067, -10.3190, -10.4728, -10.5529, -10.6402, -10.6440, -10.5113, -10.7395, -10.7870, -10.6074, -10.5033, -10.8278, -10.6384, -10.8481, -10.6875, -10.5454, -10.4747, -10.5165, -10.4930, -10.3413, -10.3472, -10.3735, -10.6830, -10.8813, -10.6338, -10.3856, -10.7727, -10.8957, -10.8068, -10.7373, -10.6108, -10.3405, -10.2889, -10.3922, -10.4946, -10.3367, -10.4164, -10.9949, -10.7196, -10.3971, -10.1734,  -9.9257,  -9.6557,  -9.1761, -9.6653,  -9.7876,  -9.7230,  -9.7792,  -9.7056,  -9.2702,  -9.4650, -9.2755,  -9.1369,  -9.1174,  -8.9197,  -8.5394,  -8.2614,  -8.1353, -8.1422,  -8.3430,  -8.6655"
#         },
#         "num_features": {
#             "string_value": "80"
#         },
#         "left_padding_size": {
#             "string_value": "1.6"
#         },
#         "sample_rate": {
#             "string_value": "16000"
#         },
#         "precalc_norm_params": {
#             "string_value": "False"
#         },
#         "use_utterance_norm_params": {
#             "string_value": "False"
#         },
#         "window_stride": {
#             "string_value": "0.01"
#         },
#         "dither": {
#             "string_value": "0.0"
#         },
#         "norm_per_feature": {
#             "string_value": "True"
#         },
#         "apply_normalization": {
#             "string_value": "True"
#         },
#         "stddev_floor": {
#             "string_value": "1e-05"
#         },
#         "chunk_size": {
#             "string_value": "4.8"
#         }
#     },
#     "model_warmup": [],
#     "model_transaction_policy": {
#         "decoupled": false
#     }
# }
# I1108 23:44:42.088575 105 endpointing_library.cc:22] TRITONBACKEND_ModelInstanceInitialize: conformer-en-US-asr-offline-endpointing-streaming-offline_0 (device 0)
# I1108 23:44:42.117079 105 ctc-decoder-library.cc:20] TRITONBACKEND_ModelInitialize: conformer-en-US-asr-offline-ctc-decoder-cpu-streaming-offline (version 1)
# I1108 23:44:42.118215 105 model_lifecycle.cc:693] successfully loaded 'conformer-en-US-asr-offline-endpointing-streaming-offline' version 1
# WARNING: Logging before InitGoogleLogging() is written to STDERR
# W1108 23:44:42.118556   111 parameter_parser.cc:144] Parameter 'append_space_to_transcripts' set but unused.
# W1108 23:44:42.118580   111 parameter_parser.cc:144] Parameter 'beam_size' set but unused.
# W1108 23:44:42.118583   111 parameter_parser.cc:144] Parameter 'beam_size_token' set but unused.
# W1108 23:44:42.118587   111 parameter_parser.cc:144] Parameter 'beam_threshold' set but unused.
# W1108 23:44:42.118588   111 parameter_parser.cc:144] Parameter 'blank_token' set but unused.
# W1108 23:44:42.118592   111 parameter_parser.cc:144] Parameter 'decoder_num_worker_threads' set but unused.
# W1108 23:44:42.118594   111 parameter_parser.cc:144] Parameter 'forerunner_beam_size' set but unused.
# W1108 23:44:42.118597   111 parameter_parser.cc:144] Parameter 'forerunner_beam_size_token' set but unused.
# W1108 23:44:42.118599   111 parameter_parser.cc:144] Parameter 'forerunner_beam_threshold' set but unused.
# W1108 23:44:42.118602   111 parameter_parser.cc:144] Parameter 'forerunner_use_lm' set but unused.
# W1108 23:44:42.118604   111 parameter_parser.cc:144] Parameter 'language_model_file' set but unused.
# W1108 23:44:42.118607   111 parameter_parser.cc:144] Parameter 'lexicon_file' set but unused.
# W1108 23:44:42.118610   111 parameter_parser.cc:144] Parameter 'lm_weight' set but unused.
# W1108 23:44:42.118613   111 parameter_parser.cc:144] Parameter 'log_add' set but unused.
# W1108 23:44:42.118615   111 parameter_parser.cc:144] Parameter 'max_execution_batch_size' set but unused.
# W1108 23:44:42.118618   111 parameter_parser.cc:144] Parameter 'max_supported_transcripts' set but unused.
# W1108 23:44:42.118620   111 parameter_parser.cc:144] Parameter 'num_tokenization' set but unused.
# W1108 23:44:42.118623   111 parameter_parser.cc:144] Parameter 'profane_words_file' set but unused.
# W1108 23:44:42.118626   111 parameter_parser.cc:144] Parameter 'set_default_index_to_unk_token' set but unused.
# W1108 23:44:42.118628   111 parameter_parser.cc:144] Parameter 'sil_token' set but unused.
# W1108 23:44:42.118631   111 parameter_parser.cc:144] Parameter 'smearing_mode' set but unused.
# W1108 23:44:42.118633   111 parameter_parser.cc:144] Parameter 'tokenizer_model' set but unused.
# W1108 23:44:42.118636   111 parameter_parser.cc:144] Parameter 'unk_score' set but unused.
# W1108 23:44:42.118638   111 parameter_parser.cc:144] Parameter 'unk_token' set but unused.
# W1108 23:44:42.118641   111 parameter_parser.cc:144] Parameter 'vocab_file' set but unused.
# W1108 23:44:42.118644   111 parameter_parser.cc:144] Parameter 'word_insertion_score' set but unused.
# I1108 23:44:42.120324 105 backend_model.cc:303] model configuration:
# {
#     "name": "conformer-en-US-asr-offline-ctc-decoder-cpu-streaming-offline",
#     "platform": "",
#     "backend": "riva_asr_decoder",
#     "version_policy": {
#         "latest": {
#             "num_versions": 1
#         }
#     },
#     "max_batch_size": 1024,
#     "input": [
#         {
#             "name": "CLASS_LOGITS",
#             "data_type": "TYPE_FP32",
#             "format": "FORMAT_NONE",
#             "dims": [
#                 -1,
#                 257
#             ],
#             "is_shape_tensor": false,
#             "allow_ragged_batch": false,
#             "optional": false
#         },
#         {
#             "name": "END_FLAG",
#             "data_type": "TYPE_UINT32",
#             "format": "FORMAT_NONE",
#             "dims": [
#                 1
#             ],
#             "is_shape_tensor": false,
#             "allow_ragged_batch": false,
#             "optional": false
#         },
#         {
#             "name": "SEGMENTS_START_END",
#             "data_type": "TYPE_FP32",
#             "format": "FORMAT_NONE",
#             "dims": [
#                 -1,
#                 2
#             ],
#             "is_shape_tensor": false,
#             "allow_ragged_batch": false,
#             "optional": false
#         },
#         {
#             "name": "CUSTOM_CONFIGURATION",
#             "data_type": "TYPE_STRING",
#             "format": "FORMAT_NONE",
#             "dims": [
#                 -1,
#                 2
#             ],
#             "is_shape_tensor": false,
#             "allow_ragged_batch": false,
#             "optional": false
#         }
#     ],
#     "output": [
#         {
#             "name": "FINAL_TRANSCRIPTS",
#             "data_type": "TYPE_STRING",
#             "dims": [
#                 -1
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         },
#         {
#             "name": "FINAL_TRANSCRIPTS_SCORE",
#             "data_type": "TYPE_FP32",
#             "dims": [
#                 -1
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         },
#         {
#             "name": "FINAL_WORDS_START_END",
#             "data_type": "TYPE_INT32",
#             "dims": [
#                 -1,
#                 2
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         },
#         {
#             "name": "PARTIAL_TRANSCRIPTS",
#             "data_type": "TYPE_STRING",
#             "dims": [
#                 -1
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         },
#         {
#             "name": "PARTIAL_TRANSCRIPTS_STABILITY",
#             "data_type": "TYPE_FP32",
#             "dims": [
#                 -1
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         },
#         {
#             "name": "PARTIAL_WORDS_START_END",
#             "data_type": "TYPE_INT32",
#             "dims": [
#                 -1,
#                 2
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         },
#         {
#             "name": "FINAL_WORDS_SCORE",
#             "data_type": "TYPE_FP32",
#             "dims": [
#                 -1
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         },
#         {
#             "name": "PARTIAL_WORDS_SCORE",
#             "data_type": "TYPE_FP32",
#             "dims": [
#                 -1
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         }
#     ],
#     "batch_input": [],
#     "batch_output": [],
#     "optimization": {
#         "graph": {
#             "level": 0
#         },
#         "priority": "PRIORITY_DEFAULT",
#         "cuda": {
#             "graphs": false,
#             "busy_wait_events": false,
#             "graph_spec": [],
#             "output_copy_stream": true
#         },
#         "input_pinned_memory": {
#             "enable": true
#         },
#         "output_pinned_memory": {
#             "enable": true
#         },
#         "gather_kernel_buffer_threshold": 0,
#         "eager_batching": false
#     },
#     "sequence_batching": {
#         "oldest": {
#             "max_candidate_sequences": 1024,
#             "preferred_batch_size": [
#                 32,
#                 64
#             ],
#             "max_queue_delay_microseconds": 1000
#         },
#         "max_sequence_idle_microseconds": 60000000,
#         "control_input": [
#             {
#                 "name": "START",
#                 "control": [
#                     {
#                         "kind": "CONTROL_SEQUENCE_START",
#                         "int32_false_true": [
#                             0,
#                             1
#                         ],
#                         "fp32_false_true": [],
#                         "bool_false_true": [],
#                         "data_type": "TYPE_INVALID"
#                     }
#                 ]
#             },
#             {
#                 "name": "READY",
#                 "control": [
#                     {
#                         "kind": "CONTROL_SEQUENCE_READY",
#                         "int32_false_true": [
#                             0,
#                             1
#                         ],
#                         "fp32_false_true": [],
#                         "bool_false_true": [],
#                         "data_type": "TYPE_INVALID"
#                     }
#                 ]
#             },
#             {
#                 "name": "END",
#                 "control": [
#                     {
#                         "kind": "CONTROL_SEQUENCE_END",
#                         "int32_false_true": [
#                             0,
#                             1
#                         ],
#                         "fp32_false_true": [],
#                         "bool_false_true": [],
#                         "data_type": "TYPE_INVALID"
#                     }
#                 ]
#             },
#             {
#                 "name": "CORRID",
#                 "control": [
#                     {
#                         "kind": "CONTROL_SEQUENCE_CORRID",
#                         "int32_false_true": [],
#                         "fp32_false_true": [],
#                         "bool_false_true": [],
#                         "data_type": "TYPE_UINT64"
#                     }
#                 ]
#             }
#         ],
#         "state": []
#     },
#     "instance_group": [
#         {
#             "name": "conformer-en-US-asr-offline-ctc-decoder-cpu-streaming-offline_0",
#             "kind": "KIND_CPU",
#             "count": 1,
#             "gpus": [],
#             "secondary_devices": [],
#             "profile": [],
#             "passive": false,
#             "host_policy": ""
#         }
#     ],
#     "default_model_filename": "",
#     "cc_model_filenames": {},
#     "metric_tags": {},
#     "parameters": {
#         "vocab_file": {
#             "string_value": "/data/models/conformer-en-US-asr-offline-ctc-decoder-cpu-streaming-offline/1/riva_decoder_vocabulary.txt"
#         },
#         "max_supported_transcripts": {
#             "string_value": "1"
#         },
#         "set_default_index_to_unk_token": {
#             "string_value": "False"
#         },
#         "decoder_num_worker_threads": {
#             "string_value": "-1"
#         },
#         "forerunner_use_lm": {
#             "string_value": "true"
#         },
#         "tokenizer_model": {
#             "string_value": "/data/models/conformer-en-US-asr-offline-ctc-decoder-cpu-streaming-offline/1/8b8f095152034e98b24ab33726708bd0_tokenizer.model"
#         },
#         "word_insertion_score": {
#             "string_value": "1.0"
#         },
#         "streaming": {
#             "string_value": "True"
#         },
#         "blank_token": {
#             "string_value": "#"
#         },
#         "num_tokenization": {
#             "string_value": "1"
#         },
#         "beam_threshold": {
#             "string_value": "20.0"
#         },
#         "left_padding_size": {
#             "string_value": "1.6"
#         },
#         "forerunner_beam_threshold": {
#             "string_value": "10.0"
#         },
#         "smearing_mode": {
#             "string_value": "max"
#         },
#         "unk_score": {
#             "string_value": "-inf"
#         },
#         "log_add": {
#             "string_value": "True"
#         },
#         "chunk_size": {
#             "string_value": "4.8"
#         },
#         "append_space_to_transcripts": {
#             "string_value": "True"
#         },
#         "beam_size": {
#             "string_value": "32"
#         },
#         "lm_weight": {
#             "string_value": "0.8"
#         },
#         "use_subword": {
#             "string_value": "True"
#         },
#         "sil_token": {
#             "string_value": "▁"
#         },
#         "beam_size_token": {
#             "string_value": "16"
#         },
#         "profane_words_file": {
#             "string_value": "/data/models/conformer-en-US-asr-offline-ctc-decoder-cpu-streaming-offline/1/profane_words_file.txt"
#         },
#         "max_execution_batch_size": {
#             "string_value": "1024"
#         },
#         "ms_per_timestep": {
#             "string_value": "40"
#         },
#         "right_padding_size": {
#             "string_value": "1.6"
#         },
#         "forerunner_beam_size": {
#             "string_value": "8"
#         },
#         "forerunner_beam_size_token": {
#             "string_value": "8"
#         },
#         "asr_model_delay": {
#             "string_value": "-1"
#         },
#         "unk_token": {
#             "string_value": "<unk>"
#         },
#         "lexicon_file": {
#             "string_value": "/data/models/conformer-en-US-asr-offline-ctc-decoder-cpu-streaming-offline/1/lexicon.txt"
#         },
#         "language_model_file": {
#             "string_value": "/data/models/conformer-en-US-asr-offline-ctc-decoder-cpu-streaming-offline/1/4gram-pruned-0_2_7_9-en-lm-set-2.0.bin"
#         },
#         "decoder_type": {
#             "string_value": "flashlight"
#         }
#     },
#     "model_warmup": [],
#     "model_transaction_policy": {
#         "decoupled": false
#     }
# }
# I1108 23:44:42.120392 105 ctc-decoder-library.cc:20] TRITONBACKEND_ModelInitialize: conformer-en-US-asr-streaming-ctc-decoder-cpu-streaming (version 1)
# W1108 23:44:42.121308   115 parameter_parser.cc:144] Parameter 'append_space_to_transcripts' set but unused.
# W1108 23:44:42.121331   115 parameter_parser.cc:144] Parameter 'beam_size' set but unused.
# W1108 23:44:42.121335   115 parameter_parser.cc:144] Parameter 'beam_size_token' set but unused.
# W1108 23:44:42.121338   115 parameter_parser.cc:144] Parameter 'beam_threshold' set but unused.
# W1108 23:44:42.121340   115 parameter_parser.cc:144] Parameter 'blank_token' set but unused.
# W1108 23:44:42.121343   115 parameter_parser.cc:144] Parameter 'decoder_num_worker_threads' set but unused.
# W1108 23:44:42.121346   115 parameter_parser.cc:144] Parameter 'forerunner_beam_size' set but unused.
# W1108 23:44:42.121349   115 parameter_parser.cc:144] Parameter 'forerunner_beam_size_token' set but unused.
# W1108 23:44:42.121351   115 parameter_parser.cc:144] Parameter 'forerunner_beam_threshold' set but unused.
# W1108 23:44:42.121354   115 parameter_parser.cc:144] Parameter 'forerunner_use_lm' set but unused.
# W1108 23:44:42.121357   115 parameter_parser.cc:144] Parameter 'language_model_file' set but unused.
# W1108 23:44:42.121361   115 parameter_parser.cc:144] Parameter 'lexicon_file' set but unused.
# W1108 23:44:42.121362   115 parameter_parser.cc:144] Parameter 'lm_weight' set but unused.
# W1108 23:44:42.121366   115 parameter_parser.cc:144] Parameter 'log_add' set but unused.
# W1108 23:44:42.121368   115 parameter_parser.cc:144] Parameter 'max_execution_batch_size' set but unused.
# W1108 23:44:42.121371   115 parameter_parser.cc:144] Parameter 'max_supported_transcripts' set but unused.
# W1108 23:44:42.121373   115 parameter_parser.cc:144] Parameter 'num_tokenization' set but unused.
# W1108 23:44:42.121376   115 parameter_parser.cc:144] Parameter 'profane_words_file' set but unused.
# W1108 23:44:42.121379   115 parameter_parser.cc:144] Parameter 'set_default_index_to_unk_token' set but unused.
# W1108 23:44:42.121381   115 parameter_parser.cc:144] Parameter 'sil_token' set but unused.
# W1108 23:44:42.121384   115 parameter_parser.cc:144] Parameter 'smearing_mode' set but unused.
# W1108 23:44:42.121387   115 parameter_parser.cc:144] Parameter 'tokenizer_model' set but unused.
# W1108 23:44:42.121389   115 parameter_parser.cc:144] Parameter 'unk_score' set but unused.
# W1108 23:44:42.121392   115 parameter_parser.cc:144] Parameter 'unk_token' set but unused.
# W1108 23:44:42.121394   115 parameter_parser.cc:144] Parameter 'vocab_file' set but unused.
# W1108 23:44:42.121397   115 parameter_parser.cc:144] Parameter 'word_insertion_score' set but unused.
# I1108 23:44:42.123021 105 backend_model.cc:303] model configuration:
# {
#     "name": "conformer-en-US-asr-streaming-ctc-decoder-cpu-streaming",
#     "platform": "",
#     "backend": "riva_asr_decoder",
#     "version_policy": {
#         "latest": {
#             "num_versions": 1
#         }
#     },
#     "max_batch_size": 1024,
#     "input": [
#         {
#             "name": "CLASS_LOGITS",
#             "data_type": "TYPE_FP32",
#             "format": "FORMAT_NONE",
#             "dims": [
#                 -1,
#                 257
#             ],
#             "is_shape_tensor": false,
#             "allow_ragged_batch": false,
#             "optional": false
#         },
#         {
#             "name": "END_FLAG",
#             "data_type": "TYPE_UINT32",
#             "format": "FORMAT_NONE",
#             "dims": [
#                 1
#             ],
#             "is_shape_tensor": false,
#             "allow_ragged_batch": false,
#             "optional": false
#         },
#         {
#             "name": "SEGMENTS_START_END",
#             "data_type": "TYPE_FP32",
#             "format": "FORMAT_NONE",
#             "dims": [
#                 -1,
#                 2
#             ],
#             "is_shape_tensor": false,
#             "allow_ragged_batch": false,
#             "optional": false
#         },
#         {
#             "name": "CUSTOM_CONFIGURATION",
#             "data_type": "TYPE_STRING",
#             "format": "FORMAT_NONE",
#             "dims": [
#                 -1,
#                 2
#             ],
#             "is_shape_tensor": false,
#             "allow_ragged_batch": false,
#             "optional": false
#         }
#     ],
#     "output": [
#         {
#             "name": "FINAL_TRANSCRIPTS",
#             "data_type": "TYPE_STRING",
#             "dims": [
#                 -1
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         },
#         {
#             "name": "FINAL_TRANSCRIPTS_SCORE",
#             "data_type": "TYPE_FP32",
#             "dims": [
#                 -1
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         },
#         {
#             "name": "FINAL_WORDS_START_END",
#             "data_type": "TYPE_INT32",
#             "dims": [
#                 -1,
#                 2
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         },
#         {
#             "name": "PARTIAL_TRANSCRIPTS",
#             "data_type": "TYPE_STRING",
#             "dims": [
#                 -1
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         },
#         {
#             "name": "PARTIAL_TRANSCRIPTS_STABILITY",
#             "data_type": "TYPE_FP32",
#             "dims": [
#                 -1
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         },
#         {
#             "name": "PARTIAL_WORDS_START_END",
#             "data_type": "TYPE_INT32",
#             "dims": [
#                 -1,
#                 2
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         },
#         {
#             "name": "FINAL_WORDS_SCORE",
#             "data_type": "TYPE_FP32",
#             "dims": [
#                 -1
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         },
#         {
#             "name": "PARTIAL_WORDS_SCORE",
#             "data_type": "TYPE_FP32",
#             "dims": [
#                 -1
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         }
#     ],
#     "batch_input": [],
#     "batch_output": [],
#     "optimization": {
#         "graph": {
#             "level": 0
#         },
#         "priority": "PRIORITY_DEFAULT",
#         "cuda": {
#             "graphs": false,
#             "busy_wait_events": false,
#             "graph_spec": [],
#             "output_copy_stream": true
#         },
#         "input_pinned_memory": {
#             "enable": true
#         },
#         "output_pinned_memory": {
#             "enable": true
#         },
#         "gather_kernel_buffer_threshold": 0,
#         "eager_batching": false
#     },
#     "sequence_batching": {
#         "oldest": {
#             "max_candidate_sequences": 1024,
#             "preferred_batch_size": [
#                 32,
#                 64
#             ],
#             "max_queue_delay_microseconds": 1000
#         },
#         "max_sequence_idle_microseconds": 60000000,
#         "control_input": [
#             {
#                 "name": "START",
#                 "control": [
#                     {
#                         "kind": "CONTROL_SEQUENCE_START",
#                         "int32_false_true": [
#                             0,
#                             1
#                         ],
#                         "fp32_false_true": [],
#                         "bool_false_true": [],
#                         "data_type": "TYPE_INVALID"
#                     }
#                 ]
#             },
#             {
#                 "name": "READY",
#                 "control": [
#                     {
#                         "kind": "CONTROL_SEQUENCE_READY",
#                         "int32_false_true": [
#                             0,
#                             1
#                         ],
#                         "fp32_false_true": [],
#                         "bool_false_true": [],
#                         "data_type": "TYPE_INVALID"
#                     }
#                 ]
#             },
#             {
#                 "name": "END",
#                 "control": [
#                     {
#                         "kind": "CONTROL_SEQUENCE_END",
#                         "int32_false_true": [
#                             0,
#                             1
#                         ],
#                         "fp32_false_true": [],
#                         "bool_false_true": [],
#                         "data_type": "TYPE_INVALID"
#                     }
#                 ]
#             },
#             {
#                 "name": "CORRID",
#                 "control": [
#                     {
#                         "kind": "CONTROL_SEQUENCE_CORRID",
#                         "int32_false_true": [],
#                         "fp32_false_true": [],
#                         "bool_false_true": [],
#                         "data_type": "TYPE_UINT64"
#                     }
#                 ]
#             }
#         ],
#         "state": []
#     },
#     "instance_group": [
#         {
#             "name": "conformer-en-US-asr-streaming-ctc-decoder-cpu-streaming_0",
#             "kind": "KIND_CPU",
#             "count": 1,
#             "gpus": [],
#             "secondary_devices": [],
#             "profile": [],
#             "passive": false,
#             "host_policy": ""
#         }
#     ],
#     "default_model_filename": "",
#     "cc_model_filenames": {},
#     "metric_tags": {},
#     "parameters": {
#         "max_execution_batch_size": {
#             "string_value": "1024"
#         },
#         "tokenizer_model": {
#             "string_value": "/data/models/conformer-en-US-asr-streaming-ctc-decoder-cpu-streaming/1/8b8f095152034e98b24ab33726708bd0_tokenizer.model"
#         },
#         "profane_words_file": {
#             "string_value": "/data/models/conformer-en-US-asr-streaming-ctc-decoder-cpu-streaming/1/profane_words_file.txt"
#         },
#         "sil_token": {
#             "string_value": "▁"
#         },
#         "decoder_type": {
#             "string_value": "flashlight"
#         },
#         "ms_per_timestep": {
#             "string_value": "40"
#         },
#         "vocab_file": {
#             "string_value": "/data/models/conformer-en-US-asr-streaming-ctc-decoder-cpu-streaming/1/riva_decoder_vocabulary.txt"
#         },
#         "smearing_mode": {
#             "string_value": "max"
#         },
#         "left_padding_size": {
#             "string_value": "1.92"
#         },
#         "use_subword": {
#             "string_value": "True"
#         },
#         "forerunner_beam_threshold": {
#             "string_value": "10.0"
#         },
#         "chunk_size": {
#             "string_value": "0.16"
#         },
#         "streaming": {
#             "string_value": "True"
#         },
#         "beam_size_token": {
#             "string_value": "16"
#         },
#         "blank_token": {
#             "string_value": "#"
#         },
#         "lm_weight": {
#             "string_value": "0.8"
#         },
#         "append_space_to_transcripts": {
#             "string_value": "True"
#         },
#         "decoder_num_worker_threads": {
#             "string_value": "-1"
#         },
#         "unk_score": {
#             "string_value": "-inf"
#         },
#         "num_tokenization": {
#             "string_value": "1"
#         },
#         "right_padding_size": {
#             "string_value": "1.92"
#         },
#         "forerunner_beam_size_token": {
#             "string_value": "8"
#         },
#         "word_insertion_score": {
#             "string_value": "1.0"
#         },
#         "asr_model_delay": {
#             "string_value": "-1"
#         },
#         "set_default_index_to_unk_token": {
#             "string_value": "False"
#         },
#         "unk_token": {
#             "string_value": "<unk>"
#         },
#         "lexicon_file": {
#             "string_value": "/data/models/conformer-en-US-asr-streaming-ctc-decoder-cpu-streaming/1/lexicon.txt"
#         },
#         "language_model_file": {
#             "string_value": "/data/models/conformer-en-US-asr-streaming-ctc-decoder-cpu-streaming/1/4gram-pruned-0_2_7_9-en-lm-set-2.0.bin"
#         },
#         "beam_threshold": {
#             "string_value": "20.0"
#         },
#         "forerunner_beam_size": {
#             "string_value": "8"
#         },
#         "log_add": {
#             "string_value": "True"
#         },
#         "max_supported_transcripts": {
#             "string_value": "1"
#         },
#         "forerunner_use_lm": {
#             "string_value": "true"
#         },
#         "beam_size": {
#             "string_value": "32"
#         }
#     },
#     "model_warmup": [],
#     "model_transaction_policy": {
#         "decoupled": false
#     }
# }
# I1108 23:44:42.123121 105 ctc-decoder-library.cc:23] TRITONBACKEND_ModelInstanceInitialize: conformer-en-US-asr-streaming-ctc-decoder-cpu-streaming_0 (device 0)
#   > Riva waiting for Triton server to load all models...retrying in 1 second
# I1108 23:44:43.742447   115 ctc-decoder.cc:174] Beam Decoder initialized successfully!
# I1108 23:44:43.742531 105 feature-extractor.cc:400] TRITONBACKEND_ModelInitialize: conformer-en-US-asr-streaming-feature-extractor-streaming (version 1)
# I1108 23:44:43.743007 105 model_lifecycle.cc:693] successfully loaded 'conformer-en-US-asr-streaming-ctc-decoder-cpu-streaming' version 1
# I1108 23:44:43.743600 105 backend_model.cc:303] model configuration:
# {
#     "name": "conformer-en-US-asr-streaming-feature-extractor-streaming",
#     "platform": "",
#     "backend": "riva_asr_features",
#     "version_policy": {
#         "latest": {
#             "num_versions": 1
#         }
#     },
#     "max_batch_size": 1024,
#     "input": [
#         {
#             "name": "AUDIO_SIGNAL",
#             "data_type": "TYPE_FP32",
#             "format": "FORMAT_NONE",
#             "dims": [
#                 -1
#             ],
#             "is_shape_tensor": false,
#             "allow_ragged_batch": false,
#             "optional": false
#         },
#         {
#             "name": "SAMPLE_RATE",
#             "data_type": "TYPE_UINT32",
#             "format": "FORMAT_NONE",
#             "dims": [
#                 1
#             ],
#             "is_shape_tensor": false,
#             "allow_ragged_batch": false,
#             "optional": false
#         }
#     ],
#     "output": [
#         {
#             "name": "AUDIO_FEATURES",
#             "data_type": "TYPE_FP32",
#             "dims": [
#                 80,
#                 -1
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         },
#         {
#             "name": "AUDIO_PROCESSED",
#             "data_type": "TYPE_FP32",
#             "dims": [
#                 1
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         },
#         {
#             "name": "AUDIO_FEATURES_LENGTH",
#             "data_type": "TYPE_INT32",
#             "dims": [
#                 1
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         }
#     ],
#     "batch_input": [],
#     "batch_output": [],
#     "optimization": {
#         "graph": {
#             "level": 0
#         },
#         "priority": "PRIORITY_DEFAULT",
#         "cuda": {
#             "graphs": false,
#             "busy_wait_events": false,
#             "graph_spec": [],
#             "output_copy_stream": true
#         },
#         "input_pinned_memory": {
#             "enable": true
#         },
#         "output_pinned_memory": {
#             "enable": true
#         },
#         "gather_kernel_buffer_threshold": 0,
#         "eager_batching": false
#     },
#     "sequence_batching": {
#         "oldest": {
#             "max_candidate_sequences": 1024,
#             "preferred_batch_size": [
#                 256,
#                 512
#             ],
#             "max_queue_delay_microseconds": 1000
#         },
#         "max_sequence_idle_microseconds": 60000000,
#         "control_input": [
#             {
#                 "name": "START",
#                 "control": [
#                     {
#                         "kind": "CONTROL_SEQUENCE_START",
#                         "int32_false_true": [
#                             0,
#                             1
#                         ],
#                         "fp32_false_true": [],
#                         "bool_false_true": [],
#                         "data_type": "TYPE_INVALID"
#                     }
#                 ]
#             },
#             {
#                 "name": "READY",
#                 "control": [
# ...
# | Backend                | Path                                                                                  | Config                                                                                                                                                         |
# +------------------------+---------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | onnxruntime            | /opt/tritonserver/backends/onnxruntime/libtriton_onnxruntime.so                       | {"cmdline":{"auto-complete-config":"false","min-compute-capability":"6.000000","backend-directory":"/opt/tritonserver/backends","default-max-batch-size":"4"}} |
# | riva_asr_endpointing   | /opt/tritonserver/backends/riva_asr_endpointing/libtriton_riva_asr_endpointing.so     | {"cmdline":{"auto-complete-config":"false","min-compute-capability":"6.000000","backend-directory":"/opt/tritonserver/backends","default-max-batch-size":"4"}} |
# | riva_nlp_detokenizer   | /opt/tritonserver/backends/riva_nlp_detokenizer/libtriton_riva_nlp_detokenizer.so     | {"cmdline":{"auto-complete-config":"false","min-compute-capability":"6.000000","backend-directory":"/opt/tritonserver/backends","default-max-batch-size":"4"}} |
# | tensorrt               | /opt/tritonserver/backends/tensorrt/libtriton_tensorrt.so                             | {"cmdline":{"auto-complete-config":"false","min-compute-capability":"6.000000","backend-directory":"/opt/tritonserver/backends","default-max-batch-size":"4"}} |
# | riva_asr_decoder       | /opt/tritonserver/backends/riva_asr_decoder/libtriton_riva_asr_decoder.so             | {"cmdline":{"auto-complete-config":"false","min-compute-capability":"6.000000","backend-directory":"/opt/tritonserver/backends","default-max-batch-size":"4"}} |
# | riva_tts_postprocessor | /opt/tritonserver/backends/riva_tts_postprocessor/libtriton_riva_tts_postprocessor.so | {"cmdline":{"auto-complete-config":"false","min-compute-capability":"6.000000","backend-directory":"/opt/tritonserver/backends","default-max-batch-size":"4"}} |
# | riva_nlp_tokenizer     | /opt/tritonserver/backends/riva_nlp_tokenizer/libtriton_riva_nlp_tokenizer.so         | {"cmdline":{"auto-complete-config":"false","min-compute-capability":"6.000000","backend-directory":"/opt/tritonserver/backends","default-max-batch-size":"4"}} |
# | riva_nlp_qa            | /opt/tritonserver/backends/riva_nlp_qa/libtriton_riva_nlp_qa.so                       | {"cmdline":{"auto-complete-config":"false","min-compute-capability":"6.000000","backend-directory":"/opt/tritonserver/backends","default-max-batch-size":"4"}} |
# | riva_asr_features      | /opt/tritonserver/backends/riva_asr_features/libtriton_riva_asr_features.so           | {"cmdline":{"auto-complete-config":"false","min-compute-capability":"6.000000","backend-directory":"/opt/tritonserver/backends","default-max-batch-size":"4"}} |
# | riva_tts_preprocessor  | /opt/tritonserver/backends/riva_tts_preprocessor/libtriton_riva_tts_preprocessor.so   | {"cmdline":{"auto-complete-config":"false","min-compute-capability":"6.000000","backend-directory":"/opt/tritonserver/backends","default-max-batch-size":"4"}} |
# | riva_nlp_pipeline      | /opt/tritonserver/backends/riva_nlp_pipeline/libtriton_riva_nlp_pipeline.so           | {"cmdline":{"auto-complete-config":"false","min-compute-capability":"6.000000","backend-directory":"/opt/tritonserver/backends","default-max-batch-size":"4"}} |
# | riva_nlp_seqlabel      | /opt/tritonserver/backends/riva_nlp_seqlabel/libtriton_riva_nlp_seqlabel.so           | {"cmdline":{"auto-complete-config":"false","min-compute-capability":"6.000000","backend-directory":"/opt/tritonserver/backends","default-max-batch-size":"4"}} |
# | riva_tts_chunker       | /opt/tritonserver/backends/riva_tts_chunker/libtriton_riva_tts_chunker.so             | {"cmdline":{"auto-complete-config":"false","min-compute-capability":"6.000000","backend-directory":"/opt/tritonserver/backends","default-max-batch-size":"4"}} |
# +------------------------+---------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# I1108 23:45:09.837415 105 server.cc:633]
# +-------------------------------------------------------------------+---------+--------+
# | Model                                                             | Version | Status |
# +-------------------------------------------------------------------+---------+--------+
# | conformer-en-US-asr-offline                                       | 1       | READY  |
# | conformer-en-US-asr-offline-ctc-decoder-cpu-streaming-offline     | 1       | READY  |
# | conformer-en-US-asr-offline-endpointing-streaming-offline         | 1       | READY  |
# | conformer-en-US-asr-offline-feature-extractor-streaming-offline   | 1       | READY  |
# | conformer-en-US-asr-streaming                                     | 1       | READY  |
# | conformer-en-US-asr-streaming-ctc-decoder-cpu-streaming           | 1       | READY  |
# | conformer-en-US-asr-streaming-endpointing-streaming               | 1       | READY  |
# | conformer-en-US-asr-streaming-feature-extractor-streaming         | 1       | READY  |
# | conformer-es-US-asr-offline                                       | 1       | READY  |
# | conformer-es-US-asr-offline-ctc-decoder-cpu-streaming-offline     | 1       | READY  |
# | conformer-es-US-asr-offline-endpointing-streaming-offline         | 1       | READY  |
# | conformer-es-US-asr-offline-feature-extractor-streaming-offline   | 1       | READY  |
# | conformer-es-US-asr-streaming                                     | 1       | READY  |
# | conformer-es-US-asr-streaming-ctc-decoder-cpu-streaming           | 1       | READY  |
# | conformer-es-US-asr-streaming-endpointing-streaming               | 1       | READY  |
# | conformer-es-US-asr-streaming-feature-extractor-streaming         | 1       | READY  |
# | fastpitch_hifigan_ensemble-English-US                             | 1       | READY  |
# | intent_slot_detokenizer                                           | 1       | READY  |
# | intent_slot_label_tokens_weather                                  | 1       | READY  |
# | intent_slot_tokenizer-en-US-weather                               | 1       | READY  |
# | qa_qa_postprocessor                                               | 1       | READY  |
# | qa_tokenizer-en-US                                                | 1       | READY  |
# | riva-onnx-fastpitch_encoder-English-US                            | 1       | READY  |
# | riva-punctuation-en-US                                            | 1       | READY  |
# | riva-punctuation-es-US                                            | 1       | READY  |
# | riva-trt-conformer-en-US-asr-offline-am-streaming-offline         | 1       | READY  |
# | riva-trt-conformer-en-US-asr-streaming-am-streaming               | 1       | READY  |
# | riva-trt-conformer-es-US-asr-offline-am-streaming-offline         | 1       | READY  |
# | riva-trt-conformer-es-US-asr-streaming-am-streaming               | 1       | READY  |
# | riva-trt-hifigan-English-US                                       | 1       | READY  |
# | riva-trt-riva-punctuation-en-US-nn-bert-base-uncased              | 1       | READY  |
# | riva-trt-riva-punctuation-es-US-nn-bert-base-multilingual-uncased | 1       | READY  |
# | riva-trt-riva_intent_weather-nn-bert-base-uncased                 | 1       | READY  |
# | riva-trt-riva_ner-nn-bert-base-uncased                            | 1       | READY  |
# | riva-trt-riva_qa-nn-bert-base-uncased                             | 1       | READY  |
# | riva-trt-riva_text_classification_domain-nn-bert-base-uncased     | 1       | READY  |
# | riva_intent_weather                                               | 1       | READY  |
# | riva_ner                                                          | 1       | READY  |
# | riva_qa                                                           | 1       | READY  |
# | riva_text_classification_domain                                   | 1       | READY  |
# | spectrogram_chunker-English-US                                    | 1       | READY  |
# | text_classification_tokenizer-en-US-domain                        | 1       | READY  |
# | token_classification_detokenizer                                  | 1       | READY  |
# | token_classification_label_tokens                                 | 1       | READY  |
# | token_classification_tokenizer-en-US                              | 1       | READY  |
# | tts_postprocessor-English-US                                      | 1       | READY  |
# | tts_preprocessor-English-US                                       | 1       | READY  |
# +-------------------------------------------------------------------+---------+--------+
#
# I1108 23:45:09.851961 105 metrics.cc:864] Collecting metrics for GPU 0: NVIDIA A10G
# I1108 23:45:09.852229 105 metrics.cc:757] Collecting CPU metrics
# I1108 23:45:09.852420 105 tritonserver.cc:2264]
# +----------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Option                           | Value                                                                                                                                                                                                |
# +----------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | server_id                        | triton                                                                                                                                                                                               |
# | server_version                   | 2.27.0                                                                                                                                                                                               |
# | server_extensions                | classification sequence model_repository model_repository(unload_dependents) schedule_policy model_configuration system_shared_memory cuda_shared_memory binary_tensor_data statistics trace logging |
# | model_repository_path[0]         | /data/models                                                                                                                                                                                         |
# | model_control_mode               | MODE_NONE                                                                                                                                                                                            |
# | strict_model_config              | 1                                                                                                                                                                                                    |
# | rate_limit                       | OFF                                                                                                                                                                                                  |
# | pinned_memory_pool_byte_size     | 268435456                                                                                                                                                                                            |
# | cuda_memory_pool_byte_size{0}    | 1000000000                                                                                                                                                                                           |
# | response_cache_byte_size         | 0                                                                                                                                                                                                    |
# | min_supported_compute_capability | 6.0                                                                                                                                                                                                  |
# | strict_readiness                 | 1                                                                                                                                                                                                    |
# | exit_timeout                     | 30                                                                                                                                                                                                   |
# +----------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# I1108 23:45:09.857333 105 grpc_server.cc:4819] Started GRPCInferenceService at 0.0.0.0:8001
# I1108 23:45:09.857561 105 http_server.cc:3474] Started HTTPService at 0.0.0.0:8000
# I1108 23:45:09.898605 105 http_server.cc:181] Started Metrics Service at 0.0.0.0:8002
#   > Triton server is ready...
# I1108 23:45:10.087963   426 riva_server.cc:125] Using Insecure Server Credentials
# I1108 23:45:10.094558   426 model_registry.cc:120] Successfully registered: conformer-en-US-asr-offline for ASR
# I1108 23:45:10.098412   426 model_registry.cc:120] Successfully registered: conformer-en-US-asr-streaming for ASR
# I1108 23:45:10.102231   426 model_registry.cc:120] Successfully registered: conformer-es-US-asr-offline for ASR
# I1108 23:45:10.106026   426 model_registry.cc:120] Successfully registered: conformer-es-US-asr-streaming for ASR
# I1108 23:45:10.185747   426 model_registry.cc:120] Successfully registered: riva-punctuation-en-US for NLP
# I1108 23:45:10.186565   426 model_registry.cc:120] Successfully registered: riva-punctuation-es-US for NLP
# I1108 23:45:10.194388   426 model_registry.cc:120] Successfully registered: riva_intent_weather for NLP
# I1108 23:45:10.195154   426 model_registry.cc:120] Successfully registered: riva_ner for NLP
# I1108 23:45:10.195919   426 model_registry.cc:120] Successfully registered: riva_qa for NLP
# I1108 23:45:10.196545   426 model_registry.cc:120] Successfully registered: riva_text_classification_domain for NLP
# W1108 23:45:10.325223   426 normalize.cc:52] Speech Class far file missing:/data/models/conformer-es-US-asr-offline/1/speech_class.far
# W1108 23:45:10.413014   426 normalize.cc:52] Speech Class far file missing:/data/models/conformer-es-US-asr-streaming/1/speech_class.far
# I1108 23:45:10.555282   426 model_registry.cc:120] Successfully registered: riva-punctuation-en-US for NLP
# I1108 23:45:10.556080   426 model_registry.cc:120] Successfully registered: riva-punctuation-es-US for NLP
# I1108 23:45:10.563735   426 model_registry.cc:120] Successfully registered: riva_intent_weather for NLP
# I1108 23:45:10.564520   426 model_registry.cc:120] Successfully registered: riva_ner for NLP
# I1108 23:45:10.565282   426 model_registry.cc:120] Successfully registered: riva_qa for NLP
# I1108 23:45:10.565919   426 model_registry.cc:120] Successfully registered: riva_text_classification_domain for NLP
# I1108 23:45:10.586835   426 model_registry.cc:120] Successfully registered: fastpitch_hifigan_ensemble-English-US for TTS
# I1108 23:45:10.648404   426 riva_server.cc:171] Riva Conversational AI Server listening on 0.0.0.0:50051
# W1108 23:45:10.648438   426 stats_reporter.cc:41] No API key provided. Stats reporting disabled.

# %% [markdown]
# ---
# # Step 2: ASR Query
# ### Listen to the Samples (not graded)

# %%
SAMPLE_1="/dli_workspace/data/usa4.wav"
SAMPLE_2="/dli_workspace/data/emea_assess_q2_resampled.wav"

print("Sample 1")
ipd.display(ipd.Audio(SAMPLE_1))

print("Sample 2")
ipd.display(ipd.Audio(SAMPLE_2))
# Out:
# Sample 1
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Sample 2
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Request ASR Transcription (graded)
# Build a function that creates and executes a transcription request from Riva. In the API request, specify:
# * English language
# * Maximum alternatives = 2
# * Punctuation enabled (true)
#
# Complete the <i><strong style="color:green;">#FIXME</strong></i> line(s) and run the next two cells to load the function into the notebook.

# %%
# Complete the functions and FIXMEs
def asr_predict(SAMPLE):
    auth = riva.client.Auth(uri='localhost:50051')
    riva_asr = riva.client.ASRService(auth)
    asr_config = riva.client.RecognitionConfig()
    asr_config.language_code = 'en-US'    # set the language code to English
    asr_config.max_alternatives = 2        # set max alternatives to two
    asr_config.enable_automatic_punctuation = True
    with io.open(SAMPLE, 'rb') as fh:
        content = fh.read()
    response = riva_asr.offline_recognize(content, asr_config)
    transcript=response.results[0].alternatives[0].transcript
    return transcript, asr_config

# %%
# Check your work.
# Did the function provide the expected transcription?
transcript, asr_config = asr_predict(SAMPLE_1)
print("ASR Transcript SAMPLE_1:", transcript)

# DO NOT REMOVE
with open('/dli/task/my_assessment/step2.txt', 'w') as f:
    f.write(str(asr_config))
# Out:
# ASR Transcript SAMPLE_1: How many States are there in the Us?

# %%
# Try with the 2nd sample
transcript, asr_config=asr_predict(SAMPLE_2)
print("ASR Transcript SAMPLE_2:", transcript)
# Out:
# ASR Transcript SAMPLE_2: How many countries in EMEA?

# %% [markdown]
# Transcribing EMEA is not accurate due to the fact that there is no such term in the lexicon.

# %% [markdown]
# ---
# # Step 3: ASR Customization
# In order to provide a correct transcription for the SAMPLE_2, please add the pronunciation for "EMEA" to the lexicon.
#
# ### Check the lexicon for the word "emea" (not graded)

# %%
import os
CONFORMER_OFFLINE = "conformer-en-US-asr-offline-ctc-decoder-cpu-streaming-offline"
LEXICON = os.path.join(RIVA_MODEL_REPO, "models", CONFORMER_OFFLINE, "1", "lexicon.txt")

! grep "^emea\b" $LEXICON

# %% [markdown]
# ### Add "emea" to the lexicon (graded)
# 1. Stop Riva
# 1. Find the tokenizer location
# 1. Get new encodings for EMEA with `sentencepiece` and the tokenizer
# 1. Complete the <i><strong style="color:green;">#FIXME</strong></i> line(s) to replace the value in the lexicon
# 1. Restart Riva

# %%
# Stop Riva
! bash $RIVA_QS/riva_stop.sh
# Out:
# Shutting down docker containers...

# %%
# Find the tokenizer
import glob
import sentencepiece as spm

# locate the _tokenizer.model in Riva models repo
mydir = os.path.join(RIVA_MODEL_REPO, "models", CONFORMER_OFFLINE, "1")
os.chdir(mydir)
for file in glob.glob("*.model"):
    filename = file
    
tokenizer = os.path.join(RIVA_MODEL_REPO, "models", CONFORMER_OFFLINE, "1", filename)

# %%
# Complete FIXMEs
# Set the token and pronuciation "emea" and transcribe it
# The token is the correct spelling; the pronunciation is simply "emea"

TOKEN="EMEA"
PRONUNCIATION="emea"
import sentencepiece as spm
s = spm.SentencePieceProcessor(model_file=tokenizer)
print(TOKEN + '\t' + ' '.join(s.encode(PRONUNCIATION, out_type=str, enable_sampling=False, alpha=0.1, nbest_size=-1)))
# Out:
# EMEA	▁e me a

# %%
# Complete the FIXME
# Add the encoded line you produced to the lexicon

! echo -e "emea\t▁e me a">> $LEXICON

# %%
# Check your work
# Was a new entry for "emea" added to the lexicon?
! grep "^emea\b" $LEXICON
# Out:
# emea	▁e me a

# %%
# Start Riva
! bash $RIVA_QS/riva_start.sh
# Out:
# Starting Riva Speech Services. This may take several minutes depending on the number of models deployed.
# 868280f52a5e89acd7cbbedd9dec088c65485f6222bda818f7a1d9cf2d98643b
# Waiting for Riva server to load all models...retrying in 10 seconds
# Waiting for Riva server to load all models...retrying in 10 seconds
# Waiting for Riva server to load all models...retrying in 10 seconds
# Riva server is ready...

# %%
# Check your work.  
# Is the transcription for "emea" spelled correctly? (don't worry about capitalization)
transcript, asr_config=asr_predict(SAMPLE_2)
print("ASR Transcript:", transcript)

# DO NOT REMOVE
with open('/dli/task/my_assessment/step3.txt', 'w') as f:
    f.write(str(transcript))
# Out:
# ASR Transcript: How many countries in Emea?

# %% [markdown]
# ---
# ### _Troubleshooting Step 3_
# _Note: A malformed lexicon entry may keep Riva from starting.  If you've "messed up" the lexicon, you can restore it to its original state by uncommenting the following cell and executing it._

# %%
BACKUP_LEXICON = os.path.join("/dli_workspace/riva-asr-model-repo", "models", CONFORMER_OFFLINE, "1", "lexicon.txt")
# !cp $BACKUP_LEXICON $LEXICON

# %% [markdown]
# ---
# # Step 4: Question Answering
# In this step, you'll first explore the QA model using an example about the USA.  Next, you'll apply what you've learned to adapt your QA to the EMEA use case.
#
# The inputs to extractive QA:
# * query - question asked
# * context - the text with the information
#
# The output from extractive QA:
# * response - answer extracted from the context, or blank if not available
#
# Define the queries and context files you will need for this section:

# %%
# Queries and content files needed for the examples
USA_CONTENT_FILE='/dli_workspace/data/usa.txt'
EMEA_CONTENT_FILE='/dli_workspace/data/emea.txt'
qa_query1 = "How many states in the US?"
qa_query2 = "What is the capital of USA?"
qa_query3 = "What does EMEA stand for?"

# %% [markdown]
# ### USA Example (not graded)

# %%
# Define a QA response dialog manager
def dm_predict(qa_query, q_context):
    auth = riva.client.Auth(uri='localhost:50051')
    nlp_service = riva.client.NLPService(auth)
    response = nlp_service.natural_query(qa_query, q_context)
    return response

# %%
# Load and display USA Context
with open(USA_CONTENT_FILE) as f:
    usa_context = f.readlines()
usa_context[0]
# Out:
# "The United States of America is a federal republic consisting of 50 states, a federal district ( Washington, D.C. , the capital city of the United States ), five major territories, and various minor islands.  Both the states and the United States as a whole are each sovereign jurisdictions. The United States of America ( U.S.A. or USA ), commonly known as the United States ( U.S. or US ) or America, is a country primarily located in North America. The United States is also in free association with three Pacific Island sovereign states: the Federated States of Micronesia, the Marshall Islands, and the Republic of Palau. It is the world's third-largest country by both land and total area.It shares land borders with Canada to its north and with Mexico to its south. It has maritime borders with the Bahamas, Cuba, Russia, and other nations.With a population of over 333 million, it is the most populous country in the Americas and the third most populous in the world. "

# %%
# QA example 1
response1 = dm_predict(qa_query1, usa_context[0])

print("Question: ", qa_query1)
print("Answer: ", response1.results[0].answer)
# Out:
# Question:  How many states in the US?
# Answer:  50

# %%
# QA example 2
response2 = dm_predict(qa_query2, usa_context[0])

print("Question: ", qa_query2)
print("Answer: ", response2.results[0].answer)
# Out:
# Question:  What is the capital of USA?
# Answer:  Washington, D.C.

# %%
# QA example 3
response3 = dm_predict(qa_query3, usa_context[0])

print("Question: ", qa_query3)
print("Answer: ", response3.results[0].answer)
# Out:
# Question:  What does EMEA stand for?
# Answer:

# %%
# Check if response is empty
if response3.results[0].answer=='' :
    print("No response to '{}'".format(qa_query3))
# Out:
# No response to 'What does EMEA stand for?'

# %% [markdown]
# ### Load the EMEA Context (graded)

# %% [markdown]
# `qa_query3` had no answer in the USA example, as expected.  This is because the USA context is focused on USA knowledge, not EMEA knowledge. Complete the <i><strong style="color:green;">#FIXME</strong></i> line(s) in the following cell and try again with EMEA knowledge.

# %%
# Complete the FIXMEs
# Check your work.  Did you get a valid answer to your question?

# Create the context
with open(EMEA_CONTENT_FILE) as f:
    emea_context = f.readlines()
    
print("------ EMEA Context File Contents ------")
print(emea_context)
print("----------------------------------------")

# Query the model with the correct context
response3 = dm_predict(qa_query3, emea_context[0])
                       
print("Question: ", qa_query3)
print("Answer: ", response3.results[0].answer)

# DO NOT REMOVE
with open('/dli/task/my_assessment/step4.txt', 'w') as f:
    f.write(str(response3))
# Out:
# ------ EMEA Context File Contents ------
# ['EMEA is a shorthand designation meaning Europe, the Middle East and Africa. The acronym is used by institutions and governments, as well as in marketing and business when referring to this region it is a shorthand way of referencing the two continents ( Africa and Europe ) and the Middle Eastern sub-continent all at once. There are roughly 115 countries and 17 non-country territories in the EMEA, but that number is not definitive.']
# ----------------------------------------
# Question:  What does EMEA stand for?
# Answer:  Europe, the Middle East and Africa.

# %% [markdown]
# ---
# # Step 5: TTS Query
#
# ### Request TTS Speech (graded)
# Complete the <i><strong style="color:green;">#FIXME</strong></i> line(s) in the following cell to configure TTS with:
# - English language
# - Correct sample_rate_hz
# - Male voice_name

# %%
# Fill in the FIXMEs for the correct configuration

sample_rate_hz = 44100

# helper function for more readable output
def remove_braces(braced_text):
    return braced_text.replace("{@","").replace("}","")

# Define a Python function to create speech from text
def tts_predict(text):
    auth = riva.client.Auth(uri='localhost:50051')
    riva_tts = riva.client.SpeechSynthesisService(auth)
    req = { 
            "language_code"  : "en-US",
            "sample_rate_hz" : sample_rate_hz,                 
            "voice_name"     : "English-US.Male-1"                    
    }
    req["text"] = text
    resp = riva_tts.synthesize(**req)
    audio_samples = np.frombuffer(resp.audio, dtype=np.int16)
    return audio_samples, remove_braces(resp.meta.processed_text), req

# %%
# Check your work.
# Is the speech output correct?

req=[]
audio_samples, processed_text, req =tts_predict(response3.results[0].answer)

# DO NOT REMOVE
with open('/dli/task/my_assessment/step5.txt', 'w') as f:
    f.write(str(req))

print(processed_text)
ipd.Audio(audio_samples, rate=sample_rate_hz)
# Out:
#  ˈjʊɹəp, THE ˈmɪdəɫ ˈist AND AFRICA.
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Customize EMEA TTS Pronunciation (not graded)

# %%
from nemo.collections.tts.models import AlignerModel
aligner = AlignerModel.from_pretrained("tts_en_radtts_aligner_ipa")
# Out:
# [NeMo I 2025-11-08 23:58:00 cloud:56] Found existing object /root/.cache/torch/NeMo/NeMo_1.14.0/Aligner/0cfa131db81f64e49f9c47f286991019/Aligner.nemo.
# [NeMo I 2025-11-08 23:58:00 cloud:62] Re-using file from: /root/.cache/torch/NeMo/NeMo_1.14.0/Aligner/0cfa131db81f64e49f9c47f286991019/Aligner.nemo
# [NeMo I 2025-11-08 23:58:00 common:912] Instantiating model from pre-trained checkpoint
# [NeMo I 2025-11-08 23:58:03 tokenize_and_classify:87] Creating ClassifyFst grammars.
# [NeMo W 2025-11-08 23:58:33 modules:344] apply_to_oov_word=None, This means that some of words will remain unchanged if they are not handled by any of the rules in self.parse_one_word(). This may be intended if phonemes and chars are both valid inputs, otherwise, you may see unexpected deletions in your input.
# [NeMo W 2025-11-08 23:58:34 modelPT:142] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.TTSDataset
#       manifest_filepath: /raid/LJSpeech/nvidia_ljspeech_train.json
#       sample_rate: 22050
#       sup_data_path: /raid/LJSpeech/aligner_train_supp/
#       sup_data_types:
#       - align_prior_matrix
#       n_fft: 1024
#       win_length: 1024
#       hop_length: 256
#       window: hann
#       n_mels: 80
#       lowfreq: 0
#       highfreq: 8000
#       max_duration: null
#       min_duration: 0.1
#       ignore_file: null
#       trim: false
#     dataloader_params:
#       drop_last: false
#       shuffle: true
#       batch_size: 64
#       num_workers: 4
#       pin_memory: true
#
# [NeMo W 2025-11-08 23:58:34 modelPT:149] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.TTSDataset
#       manifest_filepath: /raid/LJSpeech/nvidia_ljspeech_val.json
#       sample_rate: 22050
#       sup_data_path: /raid/LJSpeech/aligner_train_supp/
#       sup_data_types:
#       - align_prior_matrix
#       n_fft: 1024
#       win_length: 1024
#       hop_length: 256
#       window: hann
#       n_mels: 80
#       lowfreq: 0
#       highfreq: 8000
#       max_duration: null
#       min_duration: 0.1
#       ignore_file: null
#       trim: false
#     dataloader_params:
#       drop_last: false
#       shuffle: false
#       batch_size: 64
#       num_workers: 1
#       pin_memory: true
# [NeMo I 2025-11-08 23:58:34 features:267] PADDING: 1
# [NeMo I 2025-11-08 23:58:34 save_restore_connector:243] Model AlignerModel was successfully restored from /root/.cache/torch/NeMo/NeMo_1.14.0/Aligner/0cfa131db81f64e49f9c47f286991019/Aligner.nemo.

# %%
# some IPA options for EMEA 
# em'ea
# emea
# 'EM ˈmiə'
# EM MIA
# emia

input_string = "emia"
text_g2p = aligner.tokenizer.g2p(input_string)
print(text_g2p)
text_tokens = aligner.tokenizer(input_string)
print(text_tokens)
print("\n" + ''.join(text_g2p))
synth_audio, processed_text, req  =tts_predict(''.join(text_g2p))
ipd.display(ipd.Audio(synth_audio, rate=sample_rate_hz))
EMEA_IPA="".join(text_g2p)
# Out:
# ['E', 'M', 'I', 'A']
# [93, 26, 34, 30, 22, 93]
#
# EMIA
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
text="What does EMEA stand for?"
req=[]
C=''.join(text_g2p)
audio_samples, processed_text, req =tts_predict(text.replace("EMEA",EMEA_IPA))
print(processed_text)
ipd.Audio(audio_samples, rate=sample_rate_hz)
# Out:
#  WHAT DOES EMIA ˈstænd FOR?
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ---
# # Step 6: Simple Virtual Assistant
# Time to put the whole application together!
#
# ### Complete the Virtual Assistant Application (graded)
# Complete the <i><strong style="color:green;">#FIXME</strong></i> line(s) in the following cell and run the full pipeline.

# %%
# all together

SAMPLE="/dli_workspace/data/e_mea_assess_resampled.wav"
EMEA_CONTENT_FILE = '/dli_workspace/data/emea.txt'

print("First Audio sample:")
ipd.display(ipd.Audio(SAMPLE, rate=sample_rate_hz, autoplay=True))

with open(EMEA_CONTENT_FILE) as f:
    contents = f.read()

print("------ EMEA Context File Contents ------")
print(contents)
print("----------------------------------------")

# call Riva ASR  
transcript, asr_config = asr_predict(SAMPLE)
print("ASR Transcript SAMPLE", transcript)

clean_transcript = transcript.replace("Amea", "EMEA").replace("amea", "EMEA")

# call Dialog Manager
dm_response = dm_predict(clean_transcript, emea_context[0])
print("Dialog Manager answer:", dm_response)

# CORRECTION: Extract the text answer from dm_response
answer_text = dm_response.results[0].answer
print("Extracted answer:", answer_text)

# call Riva TTS with the EXTRACTED TEXT
synth_audio, processed_text, req = tts_predict(answer_text)

# DO NOT REMOVE
with open('/dli/task/my_assessment/step6.txt', 'w') as f:
    assessment_responses = [transcript, dm_response, processed_text]
    f.write(str(assessment_responses))

time.sleep(3)
print("Virtual Assistant Response:")
ipd.display(ipd.Audio(synth_audio, rate=sample_rate_hz, autoplay=True))
# Out:
# First Audio sample:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ------ EMEA Context File Contents ------
# EMEA is a shorthand designation meaning Europe, the Middle East and Africa. The acronym is used by institutions and governments, as well as in marketing and business when referring to this region it is a shorthand way of referencing the two continents ( Africa and Europe ) and the Middle Eastern sub-continent all at once. There are roughly 115 countries and 17 non-country territories in the EMEA, but that number is not definitive.
# ----------------------------------------
# ASR Transcript SAMPLE What Emea stands for.
# Dialog Manager answer: results {
#   answer: "a shorthand designation meaning Europe, the Middle East and Africa."
#   score: 0.32048299908638
# }
#
# Extracted answer: a shorthand designation meaning Europe, the Middle East and Africa.
# Virtual Assistant Response:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Stop Riva Services

# %%
# Shut down Riva 
# !bash $RIVA_QS/riva_stop.sh
# Out:
# Shutting down docker containers...

# %% [markdown]
# ---
# # Step 7: Submit Your Assessment
# How were your results?
#
# If you are satisfied that you have completed the code correctly, and that your virtual assistant is correct, you can submit your project as follows to the autograder:
#
# 1. Go back to the GPU launch page and click the checkmark to run the assessment:
#
# <img src="images/assess/assessment_checkmark.png">
#
# 2. That's it!  You'll receive your grade feedback in the pop-up window similar to the example below:
#
# <img src="images/assess/assessment_pass_popup.png">
#
# You can check your assessment progress in the course progress tab.  Note that partial values for the coding assessment **won't be visible here - it shows up as either 0 (if you achieve <65) or the full 70 points**.  Be sure to complete the additional questions to qualify for your final certificate!
#
# <img src="images/assess/progress.png">

# %% [markdown]
# <a href="https://www.nvidia.com/dli"> <img src="images/DLI_Header.png" alt="Header" style="width: 400px;"/> </a>
